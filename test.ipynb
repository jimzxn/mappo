# %%
import numpy as np

# %%
np.array([[1, 2, 3], [4, 5, 9, 8]],dtype=object)
# Out:
# array([list([1, 2, 3]), list([4, 5, 9, 8])], dtype=object)

# %%
np.stack([[1, 2, 3], [4, 5, 9, 8]],dtype=object)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 np.stack([[1, 2, 3], [4, 5, 9, 8]],dtype=object)
#
# File g:\anaconda\envs\python310\lib\site-packages\numpy\_core\shape_base.py:448, in stack(arrays, axis, out, dtype, casting)
#     446 shapes = {arr.shape for arr in arrays}
#     447 if len(shapes) != 1:
# --> 448     raise ValueError('all input arrays must have the same shape')
#     450 result_ndim = arrays[0].ndim + 1
#     451 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape

# %%
a=[[1,2],[1,2,3]]
np.stack(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 a=[[1,2],[1,2,3]]
# ----> 2 np.stack(a)
#
# File g:\anaconda\envs\python310\lib\site-packages\numpy\_core\shape_base.py:448, in stack(arrays, axis, out, dtype, casting)
#     446 shapes = {arr.shape for arr in arrays}
#     447 if len(shapes) != 1:
# --> 448     raise ValueError('all input arrays must have the same shape')
#     450 result_ndim = arrays[0].ndim + 1
#     451 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape
